# %% [markdown]
# # AI-Native Computer Vision Workshop: Manufacturing Quality Control
#
# This notebook is a workshop on probabilistic object detection using YOLO for PCB defect detection.
#
# Sections:
# - Business case
# - Data collection
# - Model fine-tuning (YOLO)
# - Inference & probabilistic decisioning
# - Deployment considerations
